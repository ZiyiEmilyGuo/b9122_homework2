# %% [markdown]
# ## Question 1 - 1

# %%
from bs4 import BeautifulSoup
import urllib.request

seed_url = "https://www.federalreserve.gov/newsevents/pressreleases.htm"
seed="https://www.federalreserve.gov/newsevents/pressreleases"

urls = [seed_url]    #queue of urls to crawl
seen = [seed_url]    #stack of urls seen so far
opened = []          #we keep track of seen urls so that we don't revisit them
covid=[]

maxNumUrl = 10; 
print("Starting with url="+str(urls))
while len(urls) > 0 and len(covid) < maxNumUrl:
    try:
        curr_url=urls.pop(0)
        print("num. of URLs in stack: %d " % len(urls))
        print("Trying to access= "+curr_url)
        req = urllib.request.Request(curr_url,headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urllib.request.urlopen(req).read()
        opened.append(curr_url)

    except Exception as ex:
        print("Unable to access= "+curr_url)
        print(ex)
        continue    
        
    soup = BeautifulSoup(webpage)  
    for tag in soup.find_all('a', href = True):
        childUrl = tag['href'] 
        childUrl = urllib.parse.urljoin(seed_url, childUrl)
    
        if childUrl not in seen and seed in childUrl:
            urls.append(childUrl)
            seen.append(childUrl)
            
            req_child = urllib.request.Request(childUrl,headers={'User-Agent': 'Mozilla/5.0'})
            webpage_child = urllib.request.urlopen(req_child).read()
            soup_child = BeautifulSoup(webpage_child)
            content= soup_child.get_text().lower()
            if "covid" in content:
                covid.append(childUrl)
                print("Covid URL="+childUrl)

print("num. of URLs seen = %d, and scanned = %d" % (len(seen), len(opened)))
print("List of covid URLs:")
for covid_url in covid:
    print(covid_url)
# Out:
# Starting with url=['https://www.federalreserve.gov/newsevents/pressreleases.htm']
# num. of URLs in stack: 0
# Trying to access= https://www.federalreserve.gov/newsevents/pressreleases.htm
# Covid URL=https://www.federalreserve.gov/newsevents/pressreleases/2021-press.htm
# Covid URL=https://www.federalreserve.gov/newsevents/pressreleases/2020-press.htm
# num. of URLs in stack: 21
# Trying to access= https://www.federalreserve.gov/newsevents/pressreleases.htm#content
# num. of URLs in stack: 20
# Trying to access= https://www.federalreserve.gov/newsevents/pressreleases/2022-press-fomc.htm
# Covid URL=https://www.federalreserve.gov/newsevents/pressreleases/monetary20220615a.htm
# Covid URL=https://www.federalreserve.gov/newsevents/pressreleases/monetary20220504a.htm
# Covid URL=https://www.federalreserve.gov/newsevents/pressreleases/monetary20220126a.htm
# num. of URLs in stack: 32
# Trying to access= https://www.federalreserve.gov/newsevents/pressreleases/2022-press.htm
# ...

# %% [markdown]
# ## Question 1 - 2

# %%
from bs4 import BeautifulSoup
import urllib.request

seed_url = "https://www.sec.gov/news/pressreleases"
seed = "https://www.sec.gov/news/press-release"

urls = [seed_url]    #queue of urls to crawl
seen = [seed_url]    #stack of urls seen so far
opened = []          #we keep track of seen urls so that we don't revisit them
charges=[]

maxNumUrl = 20; 
print("Starting with url="+str(urls))
while len(urls) > 0 and len(charges) < maxNumUrl:
    try:
        curr_url=urls.pop(0)
        print("num. of URLs in stack: %d " % len(urls))
        print("Trying to access= "+curr_url)
        req = urllib.request.Request(curr_url,headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urllib.request.urlopen(req).read()
        opened.append(curr_url)

    except Exception as ex:
        print("Unable to access= "+curr_url)
        print(ex)
        continue    
        
    soup = BeautifulSoup(webpage)  
    for tag in soup.find_all('a', href = True):
        childUrl = tag['href'] 
        childUrl = urllib.parse.urljoin(seed_url, childUrl)
    
        if childUrl not in seen and seed in childUrl:
            urls.append(childUrl)
            seen.append(childUrl)
            
            req_child = urllib.request.Request(childUrl,headers={'User-Agent': 'Mozilla/5.0'})
            webpage_child = urllib.request.urlopen(req_child).read()
            soup_child = BeautifulSoup(webpage_child)
            content= soup_child.get_text().lower()
            
            if "charges" in content:
                print("Covid URL="+childUrl)
                charges.append(childUrl)
               
            if len(charges) ==maxNumUrl:
                break

print("num. of URLs seen = %d, and scanned = %d" % (len(seen), len(opened)))
print("List of charges URLs:")
for charges_url in charges:
    
    req_charges = urllib.request.Request(charges_url,headers={'User-Agent': 'Mozilla/5.0'})
    webpage_charges = urllib.request.urlopen(req_charges).read()
    soup_charges = BeautifulSoup(webpage_charges)
    content= soup_charges.get_text().lower()
    
    print(charges_url)
    #print(content)
# Out:
# Starting with url=['https://www.sec.gov/news/pressreleases']
# num. of URLs in stack: 0
# Trying to access= https://www.sec.gov/news/pressreleases
# Covid URL=https://www.sec.gov/news/press-release/2022-183
# Covid URL=https://www.sec.gov/news/press-release/2022-182
# Covid URL=https://www.sec.gov/news/press-release/2022-181
# Covid URL=https://www.sec.gov/news/press-release/2022-180
# Covid URL=https://www.sec.gov/news/press-release/2022-179
# Covid URL=https://www.sec.gov/news/press-release/2022-178
# Covid URL=https://www.sec.gov/news/press-release/2022-176
# Covid URL=https://www.sec.gov/news/press-release/2022-175
# Covid URL=https://www.sec.gov/news/press-release/2022-174
# Covid URL=https://www.sec.gov/news/press-release/2022-173
# Covid URL=https://www.sec.gov/news/press-release/2022-172
# Covid URL=https://www.sec.gov/news/press-release/2022-171
# Covid URL=https://www.sec.gov/news/press-release/2022-170
# Covid URL=https://www.sec.gov/news/press-release/2022-169
# ...

# %%
charges_url="https://www.sec.gov/news/press-release/2022-186"

req_charges = urllib.request.Request(charges_url,headers={'User-Agent': 'Mozilla/5.0'})
webpage_charges = urllib.request.urlopen(req_charges).read()
soup_charges = BeautifulSoup(webpage_charges)
content= soup_charges.get_text().lower()
    
print(charges_url)
print(content)
# Out:
# https://www.sec.gov/news/press-release/2022-186
#
#
# ...
